# %% [markdown]
# <a href="https://colab.research.google.com/github/LourivalLRN/PEPP_Jose_Flavio/blob/main/PEPP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
# %matplotlib inline

# %%
data = pd.read_excel('Pasta1.xlsx')

# %%
data
# Out:
#                                   Pasta de trabalho   Planilha  \
# 0    Questionário pepp (Salvo automaticamente).xlsx  Planilha1
# 1    Questionário pepp (Salvo automaticamente).xlsx  Planilha1
# 2    Questionário pepp (Salvo automaticamente).xlsx  Planilha1
# 3    Questionário pepp (Salvo automaticamente).xlsx  Planilha1
# 4    Questionário pepp (Salvo automaticamente).xlsx  Planilha1
# ..                                              ...        ...
# 583                                 ques_peppp.xlsx  Planilha1
# 584                                 ques_peppp.xlsx  Planilha1
# 585                                 ques_peppp.xlsx  Planilha1
# 586                                 ques_peppp.xlsx  Planilha1
# 587                                 ques_peppp.xlsx  Planilha1
#
#                             Aluno  Ano Turno Sexo Raça/Etnia  Nascimento  \
# 0    Adriano Normandia Nascimento   5º     M    M      Parda     41815.0
# ...

# %%
data.isnull().sum()
# Out:
# Pasta de trabalho                                              0
# Planilha                                                       0
# Aluno                                                         24
# Ano                                                           24
# Turno                                                         24
# Sexo                                                          24
# Raça/Etnia                                                    24
# Nascimento                                                    24
# Endereco                                                      26
# Bairro                                                        24
# Telefone                                                      26
# Escolaridade do Responsável                                   23
# Ens. Fund 01 Completo                                         25
# Ens. Fund 01 Incompleto                                       26
# ...

# %%
data.loc[data['Aluno'].isnull()]
# Out:
#     Pasta de trabalho   Planilha Aluno  Ano Turno Sexo Raça/Etnia  Nascimento  \
# 564   ques_peppp.xlsx  Planilha1   NaN  NaN   NaN  NaN        NaN         NaN
# 565   ques_peppp.xlsx  Planilha1   NaN  NaN   NaN  NaN        NaN         NaN
# 566   ques_peppp.xlsx  Planilha1   NaN  NaN   NaN  NaN        NaN         NaN
# 567   ques_peppp.xlsx  Planilha1   NaN  NaN   NaN  NaN        NaN         NaN
# 568   ques_peppp.xlsx  Planilha1   NaN  NaN   NaN  NaN        NaN         NaN
# 569   ques_peppp.xlsx  Planilha1   NaN  NaN   NaN  NaN        NaN         NaN
# 570   ques_peppp.xlsx  Planilha1   NaN  NaN   NaN  NaN        NaN         NaN
# 571   ques_peppp.xlsx  Planilha1   NaN  NaN   NaN  NaN        NaN         NaN
# 572   ques_peppp.xlsx  Planilha1   NaN  NaN   NaN  NaN        NaN         NaN
# 573   ques_peppp.xlsx  Planilha1   NaN  NaN   NaN  NaN        NaN         NaN
# 574   ques_peppp.xlsx  Planilha1   NaN  NaN   NaN  NaN        NaN         NaN
# ...

# %%
data.drop(['Pasta de trabalho', 'Planilha', 'Observações', 'Endereco'], axis=1, inplace=True)

# %%
data.head(3)
# Out:
#                           Aluno Ano Turno Sexo Raça/Etnia  Nascimento  \
# 0  Adriano Normandia Nascimento  5º     M    M      Parda     41815.0
# 1     Eslloany Gonçalves Barros  5º     M    F      Parda     41432.0
# 2   Heloisa Victoria dos Santos  5º     M    F      Parda     41370.0
#
#            Bairro     Telefone     Escolaridade do Responsável  \
# 0             Km7  94992650233          Pós Graduação Completo
# 1  N.S. Aparecida  94991944674  Ensino Fundamental 01 Completo
# 2  N.S. Aparecida  94991324796                Sem Escolaridade
#
#    Ens. Fund 01 Completo  ...  O aluno possui alguma deficiencia?  \
# 0                    0.0  ...                                Não
# 1                    1.0  ...                                Não
# 2                    0.0  ...                                Não
#
#    O aluno faz algum tratamento?  O aluno já teve alguma doença grave?  \
# 0                            Não                                   Não
# ...

# %%
data.describe()
# Out:
#          Nascimento  Ens. Fund 01 Completo  Ens. Fund 01 Incompleto  \
# count    564.000000             563.000000               562.000000
# mean   42046.879433               0.056838                 0.160142
# std     1882.238236               0.231739                 0.367065
# min        5.000000               0.000000                 0.000000
# 25%    41648.750000               0.000000                 0.000000
# 50%    42035.000000               0.000000                 0.000000
# 75%    42559.250000               0.000000                 0.000000
# max    45499.000000               1.000000                 1.000000
#
#        Ens. Fund 02 Completo  Ens. Fund 02 Incompleto  Ens. Médio Completo  \
# count             563.000000               563.000000            563.00000
# mean                0.069272                 0.065719              0.39254
# std                 0.254142                 0.248011              0.48875
# ...

# %%
data.describe(include='O')
# Out:
#                                Aluno  Ano Turno Sexo Raça/Etnia    Bairro  \
# count                            564  564   564  564        564       564
# unique                           564   14     5    2          3         5
# top     Adriano Normandia Nascimento   5º     M    M      Parda  Araguaia
# freq                               1  145   285  292        453       296
#
#            Telefone Escolaridade do Responsável       Nome do Responsável  \
# count           562                         565                       564
# unique          499                          12                       517
# top     94984384544       Ensino Médio Completo  Valdene dos Santos Sousa
# freq              4                         222                         3
#
#        Com quem o aluno mora  ... O aluno possui alguma deficiencia?  \
# count                    564  ...                                564
# unique                     8  ...                                  2
# ...

# %%
data.columns
# Out:
# Index(['Aluno', 'Ano', 'Turno', 'Sexo', 'Raça/Etnia', 'Nascimento', 'Bairro',
#        'Telefone', 'Escolaridade do Responsável', 'Ens. Fund 01 Completo',
#        'Ens. Fund 01 Incompleto', 'Ens. Fund 02 Completo',
#        'Ens. Fund 02 Incompleto', 'Ens. Médio Completo',
#        'Ens. Médio Incompleto', 'Ens. Superior Completo',
#        'Ens. Superior Incompleto', 'Pós Graduação Completo',
#        'Pós Graduação Incompleto', 'Nome do Responsável',
#        'Com quem o aluno mora', 'O que o aluno gosta de comer',
#        'Renda familiar', 'Renda familiar/Salário Mínimo',
#        'Renda familiar/Abaixo Salário Mínimo',
#        'Renda familiar/Acima Salário Mínimo ', 'Aluno tem irmãos/Quantidade',
#        'Tipo de residência', 'Residencia Própria', 'Residencia Alugada',
#        'Residencia Cedida',
#        'Com quem fica o aluno durante o trabalho dos responsáveis',
#        'Quem leva/busca o aluno para as aulas?',
# ...

# %%
data.columns = ['Aluno', 'Ano', 'Turno', 'Sexo', 'RacaEtnia', 'Nascimento', 'Bairro',
       'Telefone', 'EscolaridadedoResponsavel', 'EnsFund01Completo',
       'EnsFund01Incompleto', 'EnsFund02Completo',
       'EnsFund02Incompleto', 'EnsMedioCompleto',
       'EnsMedioIncompleto', 'EnsSuperiorCompleto',
       'EnsSuperiorIncompleto', 'PosGraduacaoCompleto',
       'PosGraduacaoIncompleto', 'NomedoResponsavel',
       'ComQuemOalunoMora', 'OQueOalunoGostaDeComer',
       'Renda Familiar', 'RendaFamiliarSalarioMinimo',
       'RendaFamiliarAbaixoSalarioMinimo',
       'RendaFamiliarAcimaSalarioMinimo ', 'AlunoTemIrmaosQuantidade',
       'Tipo de Residência', 'ResidenciaPropria', 'ResidenciaAlugada',
       'ResidenciaCedida',
       'ComQuemFicaOAlunoDuranteOTrabalhoDosResponsaveis',
       'QuemLevaBuscaOAlunoParaAsAulas?',
       'OAlunoPossuiAlgumaDeficiencia?', 'OAlunoFazAlgumTratamento?',
       'OAlunoJaTeveAlgumaDoencaGrave?',
       'AlguemAjudaOAlunoNasTarefasDeCasa?', 'O Aluno é repetente?',
       'RecebeBenefioDoGoverno', 'AFamiliaCostumaLerJornaisRevistas?',
       'AFamiliaTemAcessoAComputadorCelularTv?',
       'AFamliaTemAcessoAInternet?',
       'MelhorHorarioEventos']

# %%
data.drop(['EnsFund01Completo',
       'EnsFund01Incompleto', 'EnsFund02Completo',
       'EnsFund02Incompleto', 'EnsMedioCompleto',
       'EnsMedioIncompleto', 'EnsSuperiorCompleto',
       'EnsSuperiorIncompleto', 'PosGraduacaoCompleto',
       'PosGraduacaoIncompleto'], axis=1, inplace=True)

# %%
data.drop(['ResidenciaPropria', 'ResidenciaAlugada',
       'ResidenciaCedida'], axis=1, inplace=True)

# %%
data.head()
# Out:
#                           Aluno Ano Turno Sexo RacaEtnia  Nascimento  \
# 0  Adriano Normandia Nascimento  5º     M    M     Parda     41815.0
# 1     Eslloany Gonçalves Barros  5º     M    F     Parda     41432.0
# 2   Heloisa Victoria dos Santos  5º     M    F     Parda     41370.0
# 3        Kalleby Marque Santana  5º     M    M     Parda     41456.0
# 4  Luma Victória Alves Ferreira  5º     M    F     Parda     41540.0
#
#            Bairro     Telefone         EscolaridadedoResponsavel  \
# 0             Km7  94992650233            Pós Graduação Completo
# 1  N.S. Aparecida  94991944674    Ensino Fundamental 01 Completo
# 2  N.S. Aparecida  94991324796                  Sem Escolaridade
# 3  N.S. Aparecida  94992013338  Ensino Fundamental 01 Incompleto
# 4  N.S. Aparecida  94981317601    Ensino Fundamental 01 Completo
#
#                            NomedoResponsavel  ...  \
# 0  Adriana Fernandes de Normandia Nascimento  ...
# 1                  Leiliane Campos Gonçalves  ...
# ...

# %%
pd.crosstab(data['Sexo'], data['RacaEtnia'], margins=True).style.background_gradient(cmap='OrRd')
# Out:
# <style type="text/css">
# #T_88d27_row0_col0, #T_88d27_row1_col1 {
#   background-color: #feebcf;
#   color: #000000;
# }
# #T_88d27_row0_col1, #T_88d27_row0_col3, #T_88d27_row1_col0, #T_88d27_row1_col2 {
#   background-color: #fff7ec;
#   color: #000000;
# }
# #T_88d27_row0_col2 {
#   background-color: #fff1de;
#   color: #000000;
# }
# #T_88d27_row1_col3 {
#   background-color: #feefd9;
#   color: #000000;
# }
# #T_88d27_row2_col0, #T_88d27_row2_col1, #T_88d27_row2_col2, #T_88d27_row2_col3 {
#   background-color: #7f0000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_88d27" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >RacaEtnia</th>
#       <th id="T_88d27_level0_col0" class="col_heading level0 col0" >Branca</th>
#       <th id="T_88d27_level0_col1" class="col_heading level0 col1" >Parda</th>
#       <th id="T_88d27_level0_col2" class="col_heading level0 col2" >Preta</th>
# ...

# %%
data.columns
# Out:
# Index(['Aluno', 'Ano', 'Turno', 'Sexo', 'RacaEtnia', 'Nascimento', 'Bairro',
#        'Telefone', 'EscolaridadedoResponsavel', 'NomedoResponsavel',
#        'ComQuemOalunoMora', 'OQueOalunoGostaDeComer', 'Renda Familiar',
#        'RendaFamiliarSalarioMinimo', 'RendaFamiliarAbaixoSalarioMinimo',
#        'RendaFamiliarAcimaSalarioMinimo ', 'AlunoTemIrmaosQuantidade',
#        'Tipo de Residência',
#        'ComQuemFicaOAlunoDuranteOTrabalhoDosResponsaveis',
#        'QuemLevaBuscaOAlunoParaAsAulas?', 'OAlunoPossuiAlgumaDeficiencia?',
#        'OAlunoFazAlgumTratamento?', 'OAlunoJaTeveAlgumaDoencaGrave?',
#        'AlguemAjudaOAlunoNasTarefasDeCasa?', 'O Aluno é repetente?',
#        'RecebeBenefioDoGoverno', 'AFamiliaCostumaLerJornaisRevistas?',
#        'AFamiliaTemAcessoAComputadorCelularTv?', 'AFamliaTemAcessoAInternet?',
#        'MelhorHorarioEventos'],
#       dtype='object')

# %%
data[['Sexo', 'Bairro', 'AlunoTemIrmaosQuantidade']]
# Out:
#     Sexo          Bairro  AlunoTemIrmaosQuantidade
# 0      M             Km7                       1.0
# 1      F  N.S. Aparecida                       1.0
# 2      F  N.S. Aparecida                       6.0
# 3      M  N.S. Aparecida                       1.0
# 4      F  N.S. Aparecida                       2.0
# ..   ...             ...                       ...
# 583  NaN             NaN                       NaN
# 584  NaN             NaN                       NaN
# 585  NaN             NaN                       NaN
# 586  NaN             NaN                       NaN
# 587  NaN             NaN                       NaN
#
# [588 rows x 3 columns]

# %%
data.isnull().sum()
# Out:
# Aluno                                               24
# Ano                                                 24
# Turno                                               24
# Sexo                                                24
# RacaEtnia                                           24
# Nascimento                                          24
# Bairro                                              24
# Telefone                                            26
# EscolaridadedoResponsavel                           23
# NomedoResponsavel                                   24
# ComQuemOalunoMora                                   24
# OQueOalunoGostaDeComer                              30
# Renda Familiar                                      24
# RendaFamiliarSalarioMinimo                          24
# RendaFamiliarAbaixoSalarioMinimo                    25
# RendaFamiliarAcimaSalarioMinimo                     24
# AlunoTemIrmaosQuantidade                            24
# ...

# %%
data.loc[data['AlunoTemIrmaosQuantidade'].isnull()]
# Out:
#     Aluno  Ano Turno Sexo RacaEtnia  Nascimento Bairro Telefone  \
# 564   NaN  NaN   NaN  NaN       NaN         NaN    NaN      NaN
# 565   NaN  NaN   NaN  NaN       NaN         NaN    NaN      NaN
# 566   NaN  NaN   NaN  NaN       NaN         NaN    NaN      NaN
# 567   NaN  NaN   NaN  NaN       NaN         NaN    NaN      NaN
# 568   NaN  NaN   NaN  NaN       NaN         NaN    NaN      NaN
# 569   NaN  NaN   NaN  NaN       NaN         NaN    NaN      NaN
# 570   NaN  NaN   NaN  NaN       NaN         NaN    NaN      NaN
# 571   NaN  NaN   NaN  NaN       NaN         NaN    NaN      NaN
# 572   NaN  NaN   NaN  NaN       NaN         NaN    NaN      NaN
# 573   NaN  NaN   NaN  NaN       NaN         NaN    NaN      NaN
# 574   NaN  NaN   NaN  NaN       NaN         NaN    NaN      NaN
# 575   NaN  NaN   NaN  NaN       NaN         NaN    NaN      NaN
# 576   NaN  NaN   NaN  NaN       NaN         NaN    NaN      NaN
# 577   NaN  NaN   NaN  NaN       NaN         NaN    NaN      NaN
# ...

# %%
data['AlunoTemIrmaosQuantidade'].at[182] = 0

# %%
data.loc[data['AlunoTemIrmaosQuantidade'].isnull()]
# Out:
#     Aluno  Ano Turno Sexo RacaEtnia  Nascimento Bairro Telefone  \
# 564   NaN  NaN   NaN  NaN       NaN         NaN    NaN      NaN
# 565   NaN  NaN   NaN  NaN       NaN         NaN    NaN      NaN
# 566   NaN  NaN   NaN  NaN       NaN         NaN    NaN      NaN
# 567   NaN  NaN   NaN  NaN       NaN         NaN    NaN      NaN
# 568   NaN  NaN   NaN  NaN       NaN         NaN    NaN      NaN
# 569   NaN  NaN   NaN  NaN       NaN         NaN    NaN      NaN
# 570   NaN  NaN   NaN  NaN       NaN         NaN    NaN      NaN
# 571   NaN  NaN   NaN  NaN       NaN         NaN    NaN      NaN
# 572   NaN  NaN   NaN  NaN       NaN         NaN    NaN      NaN
# 573   NaN  NaN   NaN  NaN       NaN         NaN    NaN      NaN
# 574   NaN  NaN   NaN  NaN       NaN         NaN    NaN      NaN
# 575   NaN  NaN   NaN  NaN       NaN         NaN    NaN      NaN
# 576   NaN  NaN   NaN  NaN       NaN         NaN    NaN      NaN
# 577   NaN  NaN   NaN  NaN       NaN         NaN    NaN      NaN
# ...

# %%
data.isnull().sum()
# Out:
# Aluno                                               24
# Ano                                                 24
# Turno                                               24
# Sexo                                                24
# RacaEtnia                                           24
# Nascimento                                          24
# Bairro                                              24
# Telefone                                            26
# EscolaridadedoResponsavel                           23
# NomedoResponsavel                                   24
# ComQuemOalunoMora                                   24
# OQueOalunoGostaDeComer                              30
# Renda Familiar                                      24
# RendaFamiliarSalarioMinimo                          24
# RendaFamiliarAbaixoSalarioMinimo                    25
# RendaFamiliarAcimaSalarioMinimo                     24
# AlunoTemIrmaosQuantidade                            24
# ...

# %%
indices_to_drop = list(range(564, 588))

# %%
data.drop(indices_to_drop, inplace=True)

# %%
data.isnull().sum()
# Out:
# Aluno                                               0
# Ano                                                 0
# Turno                                               0
# Sexo                                                0
# RacaEtnia                                           0
# Nascimento                                          0
# Bairro                                              0
# Telefone                                            2
# EscolaridadedoResponsavel                           0
# NomedoResponsavel                                   0
# ComQuemOalunoMora                                   0
# OQueOalunoGostaDeComer                              6
# Renda Familiar                                      0
# RendaFamiliarSalarioMinimo                          0
# RendaFamiliarAbaixoSalarioMinimo                    1
# RendaFamiliarAcimaSalarioMinimo                     0
# AlunoTemIrmaosQuantidade                            0
# ...

# %%
data['O Aluno é repetente?'].replace({'Sim': 'Sim', 'Não': 'Não'})
# Out:
# 0      Não
# 1      Não
# 2      Não
# 3      Não
# 4      Não
#       ...
# 559    Não
# 560    Não
# 561    Não
# 562    Não
# 563    Não
# Name: O Aluno é repetente?, Length: 564, dtype: object

# %%
counts, bins, patches = plt.hist(data['AlunoTemIrmaosQuantidade'], bins=10, edgecolor='black', weights=[1/len(data)]*len(data))
plt.title('Distribuição da quantidade de irmãos')
plt.xlabel('Quantidade de irmãos')
plt.ylabel('Frequência (%) dos alunos')
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: '{:.0%}'.format(y)))

plt.show()

# %%
f, ax = plt.subplots(figsize=(12,8))
data['EscolaridadedoResponsavel'].value_counts().plot.pie(explode=[0.02,0.02,0.02,0.02,0.02,0.02,0.02,0.02,0.02,0.02,0.04], autopct='%0.2f')
plt.title('Escolaridade dos Responsáveis', fontsize=(20))
ax.set_ylabel('')
plt.show()

# %%
f, ax = plt.subplots(figsize=(8,5))
data['Renda Familiar'].value_counts().plot.pie(explode=[0.02,0.02,0.02],autopct='%0.2f')
plt.title('Renda Familiar', fontsize=(19))
ax.set_ylabel('')
plt.show()

# %%
f, ax = plt.subplots(figsize=(8,5))
data['OAlunoPossuiAlgumaDeficiencia?'].value_counts().plot.pie(explode=[0.05,0.0], autopct='%0.2f')
plt.title('Quantitativo de alunos que possuem deficiência', fontsize=(19))
ax.set_ylabel('')
plt.show()

# %%
plt.figure(figsize=(9,5))
sns.countplot(data, x="Sexo", stat="percent", hue="O Aluno é repetente?", saturation=0.9)
plt.show()

# %%
plt.figure(figsize=(9,6))
ax = sns.countplot(data, x="Tipo de Residência", stat="percent", hue="Renda Familiar", saturation=0.9)
ax.set_ylabel('Porcentagem (%) de alunos')
plt.show()

# %%
plt.figure(figsize=(6,3), dpi=140)
ax =sns.countplot(data, x="RacaEtnia", stat="percent", hue="Renda Familiar", saturation=0.9)
ax.set_title("Relação entre Raça/Etnia e Renda Familiar")
ax.set_ylabel('Porcentagem (%) de alunos')
ax.set_xlabel('Raça/Etnia')

plt.show()

# %%
plt.figure(figsize=(10,5))
ax = sns.countplot(data, x="Bairro", palette='colorblind')
plt.title('Distribuição de moradia dos alunos por Bairro')
total = data['Bairro'].count()

ax.bar_label(ax.containers[0], fmt=lambda x: f'{(x/total)*100:0.2f}%')
ax.bar_label(ax.containers[1], fmt=lambda x: f'{(x/total)*100:0.2f}%')
ax.bar_label(ax.containers[2], fmt=lambda x: f'{(x/total)*100:0.2f}%')
ax.bar_label(ax.containers[3], fmt=lambda x: f'{(x/total)*100:0.2f}%')
ax.bar_label(ax.containers[4], fmt=lambda x: f'{(x/total)*100:0.2f}%')

plt.show()
# Out:
# <ipython-input-221-ee099bd75272>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data, x="Bairro", palette='colorblind')

# %%
plt.figure(figsize=(12,4), dpi=100)
ax = sns.countplot(data, x="ComQuemOalunoMora", stat="percent", palette='colorblind')

ax.set_title('Distribuição das das pessoas com quem os alunos moram')
ax.set_ylabel('Porcentagem (%) de alunos')
ax.set_xlabel('Com quem os alunos moram')

plt.show()
# Out:
# <ipython-input-222-7c9cf8e54615>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data, x="ComQuemOalunoMora", stat="percent", palette='colorblind')

# %%
plt.figure(figsize=(12,6), dpi=100)
ax = sns.countplot(data, x="ComQuemFicaOAlunoDuranteOTrabalhoDosResponsaveis", stat="percent", palette='colorblind')

ax.set_title('Distribuição de quem fica com os alunos durante o trabalho dos responsáveis')
ax.set_ylabel('Porcentagem (%) de alunos')
ax.set_xlabel('Com quem fica o alunos durante o trabalho dos responsáveis')

plt.show()
# Out:
# <ipython-input-223-72cbbb4b07e0>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data, x="ComQuemFicaOAlunoDuranteOTrabalhoDosResponsaveis", stat="percent", palette='colorblind')

# %%
plt.figure(figsize=(19,10), dpi=100)
ax = sns.countplot(data, x="QuemLevaBuscaOAlunoParaAsAulas?", stat="percent", palette='colorblind')

ax.set_title("Distribuição de quem leva/busca os alunos nas aulas")
ax.set_ylabel("Porcentagem (%) de alunos")
ax.set_xlabel("Quem leva/busca os alunos nas aulas")

plt.show()
# Out:
# <ipython-input-224-4589f2d7f003>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data, x="QuemLevaBuscaOAlunoParaAsAulas?", stat="percent", palette='colorblind')

# %%
plt.figure(figsize=(10,5), dpi=100)
ax = sns.countplot(data, x="RecebeBenefioDoGoverno", stat="percent", palette='colorblind')

ax.set_title("Distribuição dos alunos que recebem benefício do Governo", size=14)
ax.set_ylabel("Porcentagem (%) de alunos")
ax.set_xlabel("Recebe/Tipo de benefício do Governo")

plt.show()
# Out:
# <ipython-input-225-ceba24fd0522>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data, x="RecebeBenefioDoGoverno", stat="percent", palette='colorblind')

# %%
plt.figure(figsize=(10,5), dpi=100)
ax = sns.countplot(data, x="AFamliaTemAcessoAInternet?", stat="percent", palette='colorblind')

ax.set_title("Distribuição de acesso a Internet", size=14)
ax.set_ylabel("Porcentagem (%) de alunos")
ax.set_xlabel("Acesso a Internet")

plt.show()
# Out:
# <ipython-input-226-464a58a703f4>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data, x="AFamliaTemAcessoAInternet?", stat="percent", palette='colorblind')

# %%
plt.figure(figsize=(10,5), dpi=100)
ax = sns.countplot(data, x="AFamiliaTemAcessoAComputadorCelularTv?", stat="percent", palette='colorblind')

ax.set_title("Equipamentos de acesso a internet", size=14)
ax.set_ylabel("Porcentagem (%) de alunos")
ax.set_xlabel("Equipamentos")

plt.show()
# Out:
# <ipython-input-227-3e98727181e3>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data, x="AFamiliaTemAcessoAComputadorCelularTv?", stat="percent", palette='colorblind')

# %%
plt.figure(figsize=(32,15), dpi=200)
ax = sns.countplot(data, x="EscolaridadedoResponsavel", stat="percent", hue="AFamiliaCostumaLerJornaisRevistas?", saturation=0.9)

ax.set_title("Escolaridade dos Responsáveis vs Leitura de Jornais/Revista pela Família", size=25)
ax.set_ylabel("Porcentagem (%) de alunos", size=15)
ax.set_xlabel("Escolaridade dos Responsáveis", size=15)

plt.show()

# %%
plt.figure(figsize=(19,9), dpi=100)
ax = sns.countplot(data, x="AlguemAjudaOAlunoNasTarefasDeCasa?", stat="percent", palette='colorblind')

ax.set_title('Pessoas que ajudam os alunos nas tarefas escolares para casa', size=20)
ax.set_ylabel('Porcentagem (%) de alunos', size=15)
ax.set_xlabel('Pessoas que ajudam', size=15)

plt.show()
# Out:
# <ipython-input-229-a26977bbca33>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data, x="AlguemAjudaOAlunoNasTarefasDeCasa?", stat="percent", palette='colorblind')
